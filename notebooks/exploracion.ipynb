# %% [markdown]
# # Electoral Intelligence Platform - Notebook de Exploración
#
# Análisis exploratorio de comentarios de YouTube sobre la segunda vuelta presidencial Perú 2026.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('.').resolve()))

from src.utils.seed_data import generate_sample_dataframe
from src.ml.pipeline import NLPipeline
from src.analytics.metrics import PoliticalAnalytics

raw = generate_sample_dataframe(30)
pipeline = NLPipeline(sentiment_mode='TF-IDF + Logistic Regression')
df = pipeline.run(raw)
analytics = PoliticalAnalytics(df)
print(analytics.generate_conclusions())
